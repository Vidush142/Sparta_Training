# %%
import pandas as pd
import seaborn as sb

# %%
play_store_df = pd.read_csv('googleplaystore.csv')
play_store_reviews_df = pd.read_csv('googleplaystore_user_reviews.csv')

# %%
play_store_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ## Data Cleaning

# %%
play_store_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
play_store_df.duplicated().sum()
# Out:
# np.int64(483)

# %%
play_store_df.dropna(subset=['Current Ver', 'Android Ver', 'Type'], inplace=True)

# %%
play_store_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1469
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
print(play_store_df.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
play_store_df.drop_duplicates(inplace=True)

# %%
play_store_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1460
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
play_store_reviews_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
play_store_reviews_df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
play_store_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1460
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
play_store_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1460
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store_df['Rating'] = play_store_df.groupby('Category')['Rating'].transform(lambda x: x.fillna(x.mean()))

# %%
play_store_df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
app1df = play_store_df[play_store_df.Price != '0']

# %%
app1df
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# 476                        Moco+ - Chat, Meet People              DATING
# 477                                       Calculator              DATING
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#          Rating Reviews                Size  Installs  Type   Price  \
# ...

# %%
play_store_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
play_store_df['Reviews'] = play_store_df['Reviews'].astype(int)

# %%
copy_df = play_store_df

# %%
copy_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
copy_df['Rating'] = copy_df['Rating'].round(1)

# %%
copy_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store_df['Rating'] = play_store_df['Rating'].round(1)

# %%
play_store_df.drop(columns=['Current Ver', 'Android Ver'], inplace=True)

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store_df['Reviews'] = play_store_df['Reviews'].astype(int)

# %%
play_store_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# dtype: object

# %%
play_store_df['Price'] = play_store_df['Price'].str.replace('$', '')

# %%
play_store_df['Price'] = play_store_df['Price'].astype(float)

# %%
copy_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# dtype: object

# %%
play_store_df[play_store_df.Price != 0.0]
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# 476                        Moco+ - Chat, Meet People              DATING
# 477                                       Calculator              DATING
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# ...

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# dtype: object

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store_df[play_store_df.Price != 0.0]
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# 476                        Moco+ - Chat, Meet People              DATING
# 477                                       Calculator              DATING
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating  Reviews                Size  Installs  Type  Price  \
# ...

# %%
play_store_df['Installs'] = play_store_df['Installs'].str.replace(',', '')
play_store_df['Installs'] = play_store_df['Installs'].str.replace('+', '')
play_store_df['Installs'] = play_store_df['Installs'].astype(float)

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store_df['Installs'] = play_store_df['Installs'].astype(int)

# %%
play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# dtype: object

# %% [markdown]
# ### Cleaning user reviews

# %%
play_store_reviews_df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
play_store_reviews_df.duplicated().sum()
# Out:
# np.int64(33616)

# %%
play_store_reviews_df.drop_duplicates()
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
# 64236     Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
play_store_reviews_df.dropna(thresh=2, inplace=True)

# %%
play_store_reviews_df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
play_store_reviews_df.drop_duplicates(inplace=True)

# %%
play_store_reviews_df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
play_store_reviews_df.isnull().sum()
# Out:
# App                       0
# Translated_Review         5
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
play_store_reviews_df.dropna(inplace=True)

# %%
play_store_reviews_df.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
play_store_reviews_df.dtypes
# Out:
# App                        object
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %% [markdown]
# ## Visualisations

# %%
copy_df = play_store_df.copy()

# %%
copy_review_df = play_store_reviews_df.copy()

# %%
df_merged = pd.merge(copy_df, copy_review_df, on='App')

# %%
sb.boxplot(y='Rating', x='Sentiment', data=df_merged)
# Out:
# <Axes: xlabel='Sentiment', ylabel='Rating'>

# %%
sb.barplot(x='Type', y='Sentiment_Polarity', data=df_merged)
# Out:
# <Axes: xlabel='Type', ylabel='Sentiment_Polarity'>

# %%
sb.barplot(y='Category', x='Sentiment_Polarity', data=df_merged, hue='Category')
# Out:
# <Axes: xlabel='Sentiment_Polarity', ylabel='Category'>

# %%
pivot_table = df_merged.pivot_table(index='Category', values='Sentiment_Polarity', aggfunc='mean')

# %%
sb.heatmap(pivot_table,cmap='coolwarm', annot=True, linewidths=0.5)
# Out:
# <Axes: ylabel='Category'>

# %%
sb.countplot(x='Type', data=df_merged)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sb.lineplot(x='Price', y='Rating', data=df_merged)
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %%
sb.scatterplot(x='Rating', y='Installs', data=df_merged)
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>

# %%
sb.regplot(x='Rating', y='Installs', data=df_merged, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>

# %%
def categorize_rating(rating):
    if rating < 2.5:
        return 'Poor'
    elif rating < 3.5:
        return 'Average'
    elif rating < 4.5:
        return 'Good'
    else:
        return 'Excellent'

# %%
df_merged['rating_range'] = df_merged['Rating'].apply(categorize_rating)

# %%
category_mapping = {
    'ART_AND_DESIGN': 'Creative',
    'PHOTOGRAPHY': 'Creative',
    'VIDEO_PLAYERS': 'Creative',
    
    'BOOKS_AND_REFERENCE': 'Educational',
    'EDUCATION': 'Educational',
    'LIBRARIES_AND_DEMO': 'Educational',
    
    'BUSINESS': 'Productivity',
    'PRODUCTIVITY': 'Productivity',
    'FINANCE': 'Productivity',
    
    'AUTO_AND_VEHICLES': 'Utilities',
    'HOUSE_AND_HOME': 'Utilities',
    'TOOLS': 'Utilities',
    'WEATHER': 'Utilities',
    
    'HEALTH_AND_FITNESS': 'Health & Wellness',
    'MEDICAL': 'Health & Wellness',
    'PARENTING': 'Health & Wellness',
    
    'GAME': 'Entertainment',
    'ENTERTAINMENT': 'Entertainment',
    'SOCIAL': 'Entertainment',
    
    'NEWS_AND_MAGAZINES': 'Information',
    'MAPS_AND_NAVIGATION': 'Information',
    'TRAVEL_AND_LOCAL': 'Information',
    'EVENTS': 'Information',
    
    'FOOD_AND_DRINK': 'Lifestyle',
    'LIFESTYLE': 'Lifestyle',
    'SHOPPING': 'Lifestyle',
    'BEAUTY': 'Lifestyle',
    'DATING': 'Lifestyle',
    'PERSONALIZATION': 'Lifestyle',
    
    'COMMUNICATION': 'Networking',
    'SPORTS': 'Networking',
}

df_merged['Broad_Category'] = df_merged['Category'].map(category_mapping)

# %%
sb.barplot(y='Broad_Category', x='Sentiment_Polarity', data=df_merged, hue='Broad_Category', legend=False)
# Out:
# <Axes: xlabel='Sentiment_Polarity', ylabel='Broad_Category'>

# %%
sb.lineplot(data=df_merged,x='Broad_Category', y='Installs')
# Out:
# <Axes: xlabel='Broad_Category', ylabel='Installs'>

# %%
merge_copy = df_merged.copy()

# %%
creative_df = merge_copy[merge_copy.Broad_Category == 'Creative']

# %%
sb.lineplot(data=creative_df,x='Category', y='Installs')
# Out:
# <Axes: xlabel='Category', ylabel='Installs'>

# %%
creative_df
# Out:
#                                  App        Category  Rating  Reviews  Size  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9      967   14M
# 1                Coloring book moana  ART_AND_DESIGN     3.9      967   14M
# 2                Coloring book moana  ART_AND_DESIGN     3.9      967   14M
# 3                Coloring book moana  ART_AND_DESIGN     3.9      967   14M
# 4                Coloring book moana  ART_AND_DESIGN     3.9      967   14M
# ...                              ...             ...     ...      ...   ...
# 40057  FilterGrid - Cam&Photo Editor     PHOTOGRAPHY     4.6   126338  9.6M
# 40058  FilterGrid - Cam&Photo Editor     PHOTOGRAPHY     4.6   126338  9.6M
# 40059  FilterGrid - Cam&Photo Editor     PHOTOGRAPHY     4.6   126338  9.6M
# 40060  FilterGrid - Cam&Photo Editor     PHOTOGRAPHY     4.6   126338  9.6M
# 40061  FilterGrid - Cam&Photo Editor     PHOTOGRAPHY     4.6   126338  9.6M
#
# ...

# %%
sb.lineplot(data=creative_df,x='Category', y='Rating')
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %%
sb.lineplot(data=df_merged,x='Broad_Category', y='Rating')
# Out:
# <Axes: xlabel='Broad_Category', ylabel='Rating'>

# %%
pivot_table = df_merged.pivot_table(index='Sentiment', values='Rating')

# %%
sb.heatmap(pivot_table,cmap='summer', annot=True, linewidths=0.5)
# Out:
# <Axes: ylabel='Sentiment'>

# %%
sb.lineplot(data=df_merged, x="Rating", y="Installs")
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>

# %%
ir = sb.pointplot(data=df_merged, x="Rating", y="Installs")

# %%
pivot_table = df_merged.pivot_table(index='Sentiment', values='Installs')

# %%
sb.heatmap(pivot_table,cmap='summer', annot=True, linewidths=0.5)
# Out:
# <Axes: ylabel='Sentiment'>

# %%
broad_category_abbreviations = {
    'Creative': 'CRE',
    'Educational': 'EDU',
    'Productivity': 'PROD',
    'Utilities': 'UTIL',
    'Health & Wellness': 'HEALTH',
    'Entertainment': 'ENT',
    'Information': 'INFO',
    'Lifestyle': 'LIFE',
    'Networking': 'NET',
    'Other': 'OTH'
}

# %%
merge_copy['Broad_Category'] = merge_copy['Broad_Category'].map(broad_category_abbreviations)

# %%
sb.lineplot(data=merge_copy,x='Broad_Category', y='Rating')
# Out:
# <Axes: xlabel='Broad_Category', ylabel='Rating'>

# %%
merge_copy.columns = df_merged.columns.str.replace(' ', '_')

# %%
merge_copy
# Out:
#                                       App        Category  Rating  Reviews  \
# 0                     Coloring book moana  ART_AND_DESIGN     3.9      967
# 1                     Coloring book moana  ART_AND_DESIGN     3.9      967
# 2                     Coloring book moana  ART_AND_DESIGN     3.9      967
# 3                     Coloring book moana  ART_AND_DESIGN     3.9      967
# 4                     Coloring book moana  ART_AND_DESIGN     3.9      967
# ...                                   ...             ...     ...      ...
# 40409  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 40410  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 40411  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 40412  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
# 40413  Firefox Focus: The privacy browser   COMMUNICATION     4.4    36981
#
# ...

# %%
pivot_table = merge_copy.pivot_table(index='Sentiment', values='Rating')

# %%
sb.heatmap(pivot_table,cmap='summer', annot=True, linewidths=0.5)
# Out:
# <Axes: ylabel='Sentiment'>

# %%
sb.lineplot(data=df_merged, x="rating_range", y="Installs")
# Out:
# <Axes: xlabel='rating_range', ylabel='Installs'>

# %%
sb.barplot(y='Broad_Category', x='Sentiment_Polarity', data=merge_copy, hue='Broad_Category', legend=False, errorbar=None)
# Out:
# <Axes: xlabel='Sentiment_Polarity', ylabel='Broad_Category'>

# %%
sb.lineplot(data=merge_copy,x='Broad_Category', y='Rating')
# Out:
# <Axes: xlabel='Broad_Category', ylabel='Rating'>

# %%
sb.barplot(y='Broad_Category', x='Installs', data=merge_copy, hue='Broad_Category', legend=False, errorbar=None)
# Out:
# <Axes: xlabel='Installs', ylabel='Broad_Category'>

# %%
creative_df = merge_copy[merge_copy.Broad_Category == 'CRE']

# %%
sb.barplot(y='Category', x='Sentiment_Polarity', data=creative_df, errorbar=None)
# Out:
# <Axes: xlabel='Sentiment_Polarity', ylabel='Category'>

# %%
sb.lineplot(x='Category', y='Rating', data=creative_df)
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %%
sb.lineplot(x='Category', y='Installs', data=creative_df)
# Out:
# <Axes: xlabel='Category', ylabel='Installs'>
